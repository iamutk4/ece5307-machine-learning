# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import skimage.io
import skimage.transform
import urllib
import requests
from io import BytesIO

# %%
import flickrapi
api_key = '2c24b6b71e8f4b865e6142a5bb1dc41d'
api_secret = '29d78ebec5d99c6d'

flickr = flickrapi.FlickrAPI(api_key, api_secret)

# %%
keyword = 'car'
photos = flickr.walk(text=keyword, tag_mode='all', tags=keyword,extras='url_c',\
                     sort='relevance',per_page=100)

# %%
keyword1 = 'bicycle'
photos1 = flickr.walk(text=keyword1, tag_mode='all', tags=keyword1,extras='url_c',\
                     sort='relevance',per_page=100)

# %%
def disp_image(im):
    if (len(im.shape) == 2):
        # Gray scale image
        plt.imshow(im, cmap='gray')    
    else:
        # Color image.  
        im1 = (im-np.min(im))/(np.max(im)-np.min(im))*255
        im1 = im1.astype(np.uint8)
        plt.imshow(im1)    
        
    # Remove axis ticks
    plt.xticks([])
    plt.yticks([])

# %%
import os

# declare directory names
train_dir = 'train'
test_dir = 'test'
image_dir = keyword
image2_dir = keyword1

# make a directories for the training and testing images
for root_dir in [train_dir,test_dir]:
    dir_path = root_dir + '/' + image_dir
    dir_path2 = root_dir + '/' + image2_dir

    # check if data exists
    if not os.path.isdir(root_dir):
        os.mkdir(root_dir)
    if not os.path.isdir(dir_path):
        os.mkdir(dir_path)
        print("Making directory %s" % dir_path)
    else:
        print("Will store %s images in directory %s" %(root_dir,dir_path))
    if not os.path.isdir(dir_path2):
        os.mkdir(dir_path2)
        print("Making directory %s" % dir_path2)
    else:
        print("Will store %s images in directory %s" %(root_dir,dir_path2))
# Out:
# Making directory train/car
# Making directory train/bicycle
# Making directory test/car
# Making directory test/bicycle

# %%
import warnings
from random import seed
from random import random
    
ntrain = 1000 # number of training images to download
ntest = 300 # number of testing images to download

nrow = 224 # image dimension 1
ncol = 224 # image dimension 2

# download images, first train then test
seed(1) # make repeatable
itrain = 0 # initialize counter
itest = 0 # initialize counter
for photo in photos:
    url=photo.get('url_c')
    if not (url is None):
        
        # Create a file from the URL
        # This may only work in Python3
        response = requests.get(url)
        file = BytesIO(response.content)
        
        # Read image from file
        im = skimage.io.imread(file)
        
        # Resize images
        im1 = skimage.transform.resize(im,(nrow,ncol),mode='constant')
                
        # Convert to uint8, suppress the warning about the precision loss
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            im2 = skimage.img_as_ubyte(im1)
    
        # Set the directory randomly 
        #if (random()< ntrain/(ntrain+ntest)):
        if (random()< (ntrain-itrain)/(ntrain-itrain + ntest-itest + 1e-15)):
            if (itrain<ntrain):
                dir_path = train_dir + '/' + image_dir
                i = itrain
                itrain = itrain + 1
            elif (itest<ntest):
                dir_path = test_dir + '/' + image_dir
                i = itest
                itest = itest + 1
            else:
                break
        else:
            if (itest<ntest):
                dir_path = test_dir + '/' + image_dir
                i = itest
                itest = itest + 1
            elif (itrain<ntrain):
                dir_path = train_dir + '/' + image_dir
                i = itrain
                itrain = itrain + 1
            else:
                break            
    
        # Save the image
        local_name = '{0:s}/{1:s}_{2:04d}.jpg'.format(dir_path,keyword,i)  
        skimage.io.imsave(local_name, im2)      
        print(local_name)
# test/car/car_0281.jpg
# test/car/car_0282.jpg
# train/car/car_0937.jpg
# train/car/car_0938.jpg
# train/car/car_0939.jpg
# train/car/car_0940.jpg
# train/car/car_0941.jpg
# train/car/car_0942.jpg
# train/car/car_0943.jpg
# train/car/car_0944.jpg
# test/car/car_0283.jpg
# train/car/car_0945.jpg
# train/car/car_0946.jpg
# test/car/car_0284.jpg
# test/car/car_0285.jpg
# test/car/car_0286.jpg
# train/car/car_0947.jpg
# train/car/car_0948.jpg
# train/car/car_0949.jpg
# train/car/car_0950.jpg
# test/car/car_0287.jpg
# train/car/car_0951.jpg
# train/car/car_0952.jpg
# train/car/car_0953.jpg
# test/car/car_0288.jpg
# test/car/car_0289.jpg
# test/car/car_0290.jpg
# train/car/car_0954.jpg
# train/car/car_0955.jpg
# train/car/car_0956.jpg
# train/car/car_0957.jpg
# test/car/car_0291.jpg
# test/car/car_0292.jpg
# train/car/car_0958.jpg
# train/car/car_0959.jpg
# train/car/car_0960.jpg
# train/car/car_0961.jpg
# train/car/car_0962.jpg
# test/car/car_0293.jpg
# train/car/car_0963.jpg
# train/car/car_0964.jpg
# train/car/car_0965.jpg
# train/car/car_0966.jpg
# train/car/car_0967.jpg
# train/car/car_0968.jpg
# train/car/car_0969.jpg
# train/car/car_0970.jpg
# train/car/car_0971.jpg
# train/car/car_0972.jpg
# train/car/car_0973.jpg
# train/car/car_0974.jpg
# train/car/car_0975.jpg
# test/car/car_0294.jpg
# train/car/car_0976.jpg
# train/car/car_0977.jpg
# test/car/car_0295.jpg
# train/car/car_0978.jpg
# train/car/car_0979.jpg
# train/car/car_0980.jpg
# train/car/car_0981.jpg
# test/car/car_0296.jpg
# train/car/car_0982.jpg
# train/car/car_0983.jpg
# train/car/car_0984.jpg
# train/car/car_0985.jpg
# train/car/car_0986.jpg
# train/car/car_0987.jpg
# train/car/car_0988.jpg
# train/car/car_0989.jpg
# train/car/car_0990.jpg
# train/car/car_0991.jpg
# test/car/car_0297.jpg
# train/car/car_0992.jpg
# train/car/car_0993.jpg
# train/car/car_0994.jpg
# test/car/car_0298.jpg
# train/car/car_0995.jpg
# train/car/car_0996.jpg
# train/car/car_0997.jpg
# train/car/car_0998.jpg
# train/car/car_0999.jpg
# test/car/car_0299.jpg

# %%
import warnings
from random import seed
from random import random
    
ntrain = 1000 # number of training images to download
ntest = 300 # number of testing images to download

nrow = 224 # image dimension 1
ncol = 224 # image dimension 2

# download images, first train then test
seed(1) # make repeatable
itrain = 0 # initialize counter
itest = 0 # initialize counter
for photo in photos1:
    url=photo.get('url_c')
    if not (url is None):
        
        # Create a file from the URL
        # This may only work in Python3
        response = requests.get(url)
        file = BytesIO(response.content)
        
        # Read image from file
        im = skimage.io.imread(file)
        
        # Resize images
        im1 = skimage.transform.resize(im,(nrow,ncol),mode='constant')
                
        # Convert to uint8, suppress the warning about the precision loss
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            im2 = skimage.img_as_ubyte(im1)
    
        # Set the directory randomly 
        #if (random()< ntrain/(ntrain+ntest)):
        if (random()< (ntrain-itrain)/(ntrain-itrain + ntest-itest + 1e-15)):
            if (itrain<ntrain):
                dir_path2 = train_dir + '/' + image2_dir
                i = itrain
                itrain = itrain + 1
            elif (itest<ntest):
                dir_path2 = test_dir + '/' + image2_dir
                i = itest
                itest = itest + 1
            else:
                break
        else:
            if (itest<ntest):
                dir_path2 = test_dir + '/' + image2_dir
                i = itest
                itest = itest + 1
            elif (itrain<ntrain):
                dir_path2 = train_dir + '/' + image2_dir
                i = itrain
                itrain = itrain + 1
            else:
                break            
    
        # Save the image
        local_name = '{0:s}/{1:s}_{2:04d}.jpg'.format(dir_path2,keyword1,i)  
        skimage.io.imsave(local_name, im2)      
        print(local_name)
# Out:
# train/bicycle/bicycle_0000.jpg
# test/bicycle/bicycle_0000.jpg
# train/bicycle/bicycle_0001.jpg
# train/bicycle/bicycle_0002.jpg
# train/bicycle/bicycle_0003.jpg
# train/bicycle/bicycle_0004.jpg
# train/bicycle/bicycle_0005.jpg
# test/bicycle/bicycle_0001.jpg
# train/bicycle/bicycle_0006.jpg
# train/bicycle/bicycle_0007.jpg
# test/bicycle/bicycle_0002.jpg
# train/bicycle/bicycle_0008.jpg
# train/bicycle/bicycle_0009.jpg
# train/bicycle/bicycle_0010.jpg
# train/bicycle/bicycle_0011.jpg
# train/bicycle/bicycle_0012.jpg
# train/bicycle/bicycle_0013.jpg
# test/bicycle/bicycle_0003.jpg
# test/bicycle/bicycle_0004.jpg
# train/bicycle/bicycle_0014.jpg
# train/bicycle/bicycle_0015.jpg
# train/bicycle/bicycle_0016.jpg
# test/bicycle/bicycle_0005.jpg
# train/bicycle/bicycle_0017.jpg
# train/bicycle/bicycle_0018.jpg
# train/bicycle/bicycle_0019.jpg
# train/bicycle/bicycle_0020.jpg
# train/bicycle/bicycle_0021.jpg
# train/bicycle/bicycle_0022.jpg
# train/bicycle/bicycle_0023.jpg
# train/bicycle/bicycle_0024.jpg
# train/bicycle/bicycle_0025.jpg
# train/bicycle/bicycle_0026.jpg
# train/bicycle/bicycle_0027.jpg
# train/bicycle/bicycle_0028.jpg
# train/bicycle/bicycle_0029.jpg
# test/bicycle/bicycle_0006.jpg
# train/bicycle/bicycle_0030.jpg
# train/bicycle/bicycle_0031.jpg
# train/bicycle/bicycle_0032.jpg
# test/bicycle/bicycle_0007.jpg
# test/bicycle/bicycle_0008.jpg
# train/bicycle/bicycle_0033.jpg
# train/bicycle/bicycle_0034.jpg
# train/bicycle/bicycle_0035.jpg
# train/bicycle/bicycle_0036.jpg
# test/bicycle/bicycle_0009.jpg
# train/bicycle/bicycle_0037.jpg
# test/bicycle/bicycle_0010.jpg
# train/bicycle/bicycle_0038.jpg
# train/bicycle/bicycle_0039.jpg
# train/bicycle/bicycle_0040.jpg
# test/bicycle/bicycle_0011.jpg
# test/bicycle/bicycle_0012.jpg
# train/bicycle/bicycle_0041.jpg
# train/bicycle/bicycle_0042.jpg
# train/bicycle/bicycle_0043.jpg
# train/bicycle/bicycle_0044.jpg
# test/bicycle/bicycle_0013.jpg
# train/bicycle/bicycle_0045.jpg
# train/bicycle/bicycle_0046.jpg
# train/bicycle/bicycle_0047.jpg
# train/bicycle/bicycle_0048.jpg
# train/bicycle/bicycle_0049.jpg
# train/bicycle/bicycle_0050.jpg
# train/bicycle/bicycle_0051.jpg
# train/bicycle/bicycle_0052.jpg
# test/bicycle/bicycle_0014.jpg
# train/bicycle/bicycle_0053.jpg
# train/bicycle/bicycle_0054.jpg
# train/bicycle/bicycle_0055.jpg
# train/bicycle/bicycle_0056.jpg
# train/bicycle/bicycle_0057.jpg
# train/bicycle/bicycle_0058.jpg
# test/bicycle/bicycle_0015.jpg
# train/bicycle/bicycle_0059.jpg
# train/bicycle/bicycle_0060.jpg
# train/bicycle/bicycle_0061.jpg
# train/bicycle/bicycle_0062.jpg
# test/bicycle/bicycle_0016.jpg
# test/bicycle/bicycle_0017.jpg
# train/bicycle/bicycle_0063.jpg
# test/bicycle/bicycle_0018.jpg
# train/bicycle/bicycle_0064.jpg
# train/bicycle/bicycle_0065.jpg
# test/bicycle/bicycle_0019.jpg
# train/bicycle/bicycle_0066.jpg
# train/bicycle/bicycle_0067.jpg
# train/bicycle/bicycle_0068.jpg
# train/bicycle/bicycle_0069.jpg
# test/bicycle/bicycle_0020.jpg
# train/bicycle/bicycle_0070.jpg
# test/bicycle/bicycle_0021.jpg
# test/bicycle/bicycle_0022.jpg
# test/bicycle/bicycle_0023.jpg
# train/bicycle/bicycle_0071.jpg
# test/bicycle/bicycle_0024.jpg
# train/bicycle/bicycle_0072.jpg
# train/bicycle/bicycle_0073.jpg
# train/bicycle/bicycle_0074.jpg
# train/bicycle/bicycle_0075.jpg
# test/bicycle/bicycle_0025.jpg
# train/bicycle/bicycle_0076.jpg
# train/bicycle/bicycle_0077.jpg
# train/bicycle/bicycle_0078.jpg
# train/bicycle/bicycle_0079.jpg
# train/bicycle/bicycle_0080.jpg
# train/bicycle/bicycle_0081.jpg
# train/bicycle/bicycle_0082.jpg
# train/bicycle/bicycle_0083.jpg
# train/bicycle/bicycle_0084.jpg
# train/bicycle/bicycle_0085.jpg
# train/bicycle/bicycle_0086.jpg
# train/bicycle/bicycle_0087.jpg
# train/bicycle/bicycle_0088.jpg
# train/bicycle/bicycle_0089.jpg
# test/bicycle/bicycle_0026.jpg
# test/bicycle/bicycle_0027.jpg
# test/bicycle/bicycle_0028.jpg
# test/bicycle/bicycle_0029.jpg
# train/bicycle/bicycle_0090.jpg
# test/bicycle/bicycle_0030.jpg
# train/bicycle/bicycle_0091.jpg
# train/bicycle/bicycle_0092.jpg
# train/bicycle/bicycle_0093.jpg
# train/bicycle/bicycle_0094.jpg
# train/bicycle/bicycle_0095.jpg
# train/bicycle/bicycle_0096.jpg
# train/bicycle/bicycle_0097.jpg
# train/bicycle/bicycle_0098.jpg
# train/bicycle/bicycle_0099.jpg
# train/bicycle/bicycle_0100.jpg
# train/bicycle/bicycle_0101.jpg
# train/bicycle/bicycle_0102.jpg
# train/bicycle/bicycle_0103.jpg
# train/bicycle/bicycle_0104.jpg
# train/bicycle/bicycle_0105.jpg
# train/bicycle/bicycle_0106.jpg
# train/bicycle/bicycle_0107.jpg
# train/bicycle/bicycle_0108.jpg
# train/bicycle/bicycle_0109.jpg
# train/bicycle/bicycle_0110.jpg
# train/bicycle/bicycle_0111.jpg
# train/bicycle/bicycle_0112.jpg
# train/bicycle/bicycle_0113.jpg
# test/bicycle/bicycle_0031.jpg
# train/bicycle/bicycle_0114.jpg
# train/bicycle/bicycle_0115.jpg
# train/bicycle/bicycle_0116.jpg
# test/bicycle/bicycle_0032.jpg
# train/bicycle/bicycle_0117.jpg
# train/bicycle/bicycle_0118.jpg
# train/bicycle/bicycle_0119.jpg
# train/bicycle/bicycle_0120.jpg
# train/bicycle/bicycle_0121.jpg
# train/bicycle/bicycle_0122.jpg
# train/bicycle/bicycle_0123.jpg
# train/bicycle/bicycle_0124.jpg
# train/bicycle/bicycle_0125.jpg
# test/bicycle/bicycle_0033.jpg
# test/bicycle/bicycle_0034.jpg
# train/bicycle/bicycle_0126.jpg
# train/bicycle/bicycle_0127.jpg
# train/bicycle/bicycle_0128.jpg
# train/bicycle/bicycle_0129.jpg
# train/bicycle/bicycle_0130.jpg
# train/bicycle/bicycle_0131.jpg
# train/bicycle/bicycle_0132.jpg
# train/bicycle/bicycle_0133.jpg
# train/bicycle/bicycle_0134.jpg
# test/bicycle/bicycle_0035.jpg
# test/bicycle/bicycle_0036.jpg
# train/bicycle/bicycle_0135.jpg
# test/bicycle/bicycle_0037.jpg
# train/bicycle/bicycle_0136.jpg
# test/bicycle/bicycle_0038.jpg
# train/bicycle/bicycle_0137.jpg
# train/bicycle/bicycle_0138.jpg
# train/bicycle/bicycle_0139.jpg
# train/bicycle/bicycle_0140.jpg
# test/bicycle/bicycle_0039.jpg
# train/bicycle/bicycle_0141.jpg
# test/bicycle/bicycle_0040.jpg
# test/bicycle/bicycle_0041.jpg
# train/bicycle/bicycle_0142.jpg
# train/bicycle/bicycle_0143.jpg
# test/bicycle/bicycle_0042.jpg
# test/bicycle/bicycle_0043.jpg
# train/bicycle/bicycle_0144.jpg
# train/bicycle/bicycle_0145.jpg
# train/bicycle/bicycle_0146.jpg
# train/bicycle/bicycle_0147.jpg
# train/bicycle/bicycle_0148.jpg
# train/bicycle/bicycle_0149.jpg
# train/bicycle/bicycle_0150.jpg
# train/bicycle/bicycle_0151.jpg
# train/bicycle/bicycle_0152.jpg
# train/bicycle/bicycle_0153.jpg
# train/bicycle/bicycle_0154.jpg
# train/bicycle/bicycle_0155.jpg
# train/bicycle/bicycle_0156.jpg
# test/bicycle/bicycle_0044.jpg
# test/bicycle/bicycle_0045.jpg
# train/bicycle/bicycle_0157.jpg
# train/bicycle/bicycle_0158.jpg
# train/bicycle/bicycle_0159.jpg
# test/bicycle/bicycle_0046.jpg
# test/bicycle/bicycle_0047.jpg
# train/bicycle/bicycle_0160.jpg
# train/bicycle/bicycle_0161.jpg
# train/bicycle/bicycle_0162.jpg
# test/bicycle/bicycle_0048.jpg
# test/bicycle/bicycle_0049.jpg
# train/bicycle/bicycle_0163.jpg
# test/bicycle/bicycle_0050.jpg
# train/bicycle/bicycle_0164.jpg
# train/bicycle/bicycle_0165.jpg
# test/bicycle/bicycle_0051.jpg
# train/bicycle/bicycle_0166.jpg
# train/bicycle/bicycle_0167.jpg
# train/bicycle/bicycle_0168.jpg
# train/bicycle/bicycle_0169.jpg
# test/bicycle/bicycle_0052.jpg
# train/bicycle/bicycle_0170.jpg
# train/bicycle/bicycle_0171.jpg
# train/bicycle/bicycle_0172.jpg
# test/bicycle/bicycle_0053.jpg
# train/bicycle/bicycle_0173.jpg
# train/bicycle/bicycle_0174.jpg
# train/bicycle/bicycle_0175.jpg
# test/bicycle/bicycle_0054.jpg
# train/bicycle/bicycle_0176.jpg
# test/bicycle/bicycle_0055.jpg
# test/bicycle/bicycle_0056.jpg
# train/bicycle/bicycle_0177.jpg
# train/bicycle/bicycle_0178.jpg
# train/bicycle/bicycle_0179.jpg
# train/bicycle/bicycle_0180.jpg
# train/bicycle/bicycle_0181.jpg
# test/bicycle/bicycle_0057.jpg
# test/bicycle/bicycle_0058.jpg
# test/bicycle/bicycle_0059.jpg
# train/bicycle/bicycle_0182.jpg
# train/bicycle/bicycle_0183.jpg
# test/bicycle/bicycle_0060.jpg
# train/bicycle/bicycle_0184.jpg
# train/bicycle/bicycle_0185.jpg
# train/bicycle/bicycle_0186.jpg
# train/bicycle/bicycle_0187.jpg
# train/bicycle/bicycle_0188.jpg
# test/bicycle/bicycle_0061.jpg
# train/bicycle/bicycle_0189.jpg
# test/bicycle/bicycle_0062.jpg
# train/bicycle/bicycle_0190.jpg
# train/bicycle/bicycle_0191.jpg
# test/bicycle/bicycle_0063.jpg
# test/bicycle/bicycle_0064.jpg
# train/bicycle/bicycle_0192.jpg
# train/bicycle/bicycle_0193.jpg
# train/bicycle/bicycle_0194.jpg
# train/bicycle/bicycle_0195.jpg
# test/bicycle/bicycle_0065.jpg
# train/bicycle/bicycle_0196.jpg
# train/bicycle/bicycle_0197.jpg
# test/bicycle/bicycle_0066.jpg
# train/bicycle/bicycle_0198.jpg
# train/bicycle/bicycle_0199.jpg
# train/bicycle/bicycle_0200.jpg
# train/bicycle/bicycle_0201.jpg
# train/bicycle/bicycle_0202.jpg
# train/bicycle/bicycle_0203.jpg
# test/bicycle/bicycle_0067.jpg
# train/bicycle/bicycle_0204.jpg
# test/bicycle/bicycle_0068.jpg
# test/bicycle/bicycle_0069.jpg
# train/bicycle/bicycle_0205.jpg
# train/bicycle/bicycle_0206.jpg
# train/bicycle/bicycle_0207.jpg
# train/bicycle/bicycle_0208.jpg
# train/bicycle/bicycle_0209.jpg
# train/bicycle/bicycle_0210.jpg
# train/bicycle/bicycle_0211.jpg
# test/bicycle/bicycle_0070.jpg
# train/bicycle/bicycle_0212.jpg
# train/bicycle/bicycle_0213.jpg
# train/bicycle/bicycle_0214.jpg
# train/bicycle/bicycle_0215.jpg
# train/bicycle/bicycle_0216.jpg
# test/bicycle/bicycle_0071.jpg
# test/bicycle/bicycle_0072.jpg
# test/bicycle/bicycle_0073.jpg
# train/bicycle/bicycle_0217.jpg
# train/bicycle/bicycle_0218.jpg
# train/bicycle/bicycle_0219.jpg
# test/bicycle/bicycle_0074.jpg
# train/bicycle/bicycle_0220.jpg
# train/bicycle/bicycle_0221.jpg
# train/bicycle/bicycle_0222.jpg
# train/bicycle/bicycle_0223.jpg
# train/bicycle/bicycle_0224.jpg
# train/bicycle/bicycle_0225.jpg
# train/bicycle/bicycle_0226.jpg
# train/bicycle/bicycle_0227.jpg
# train/bicycle/bicycle_0228.jpg
# test/bicycle/bicycle_0075.jpg
# train/bicycle/bicycle_0229.jpg
# train/bicycle/bicycle_0230.jpg
# train/bicycle/bicycle_0231.jpg
# test/bicycle/bicycle_0076.jpg
# train/bicycle/bicycle_0232.jpg
# train/bicycle/bicycle_0233.jpg
# train/bicycle/bicycle_0234.jpg
# train/bicycle/bicycle_0235.jpg
# test/bicycle/bicycle_0077.jpg
# test/bicycle/bicycle_0078.jpg
# train/bicycle/bicycle_0236.jpg
# train/bicycle/bicycle_0237.jpg
# train/bicycle/bicycle_0238.jpg
# train/bicycle/bicycle_0239.jpg
# train/bicycle/bicycle_0240.jpg
# train/bicycle/bicycle_0241.jpg
# train/bicycle/bicycle_0242.jpg
# train/bicycle/bicycle_0243.jpg
# train/bicycle/bicycle_0244.jpg
# train/bicycle/bicycle_0245.jpg
# train/bicycle/bicycle_0246.jpg
# train/bicycle/bicycle_0247.jpg
# train/bicycle/bicycle_0248.jpg
# train/bicycle/bicycle_0249.jpg
# test/bicycle/bicycle_0079.jpg
# train/bicycle/bicycle_0250.jpg
# test/bicycle/bicycle_0080.jpg
# train/bicycle/bicycle_0251.jpg
# train/bicycle/bicycle_0252.jpg
# test/bicycle/bicycle_0081.jpg
# train/bicycle/bicycle_0253.jpg
# test/bicycle/bicycle_0082.jpg
# train/bicycle/bicycle_0254.jpg
# test/bicycle/bicycle_0083.jpg
# test/bicycle/bicycle_0084.jpg
# test/bicycle/bicycle_0085.jpg
# train/bicycle/bicycle_0255.jpg
# train/bicycle/bicycle_0256.jpg
# train/bicycle/bicycle_0257.jpg
# test/bicycle/bicycle_0086.jpg
# train/bicycle/bicycle_0258.jpg
# test/bicycle/bicycle_0087.jpg
# train/bicycle/bicycle_0259.jpg
# test/bicycle/bicycle_0088.jpg
# train/bicycle/bicycle_0260.jpg
# train/bicycle/bicycle_0261.jpg
# test/bicycle/bicycle_0089.jpg
# test/bicycle/bicycle_0090.jpg
# test/bicycle/bicycle_0091.jpg
# test/bicycle/bicycle_0092.jpg
# train/bicycle/bicycle_0262.jpg
# train/bicycle/bicycle_0263.jpg
# train/bicycle/bicycle_0264.jpg
# train/bicycle/bicycle_0265.jpg
# train/bicycle/bicycle_0266.jpg
# train/bicycle/bicycle_0267.jpg
# train/bicycle/bicycle_0268.jpg
# train/bicycle/bicycle_0269.jpg
# train/bicycle/bicycle_0270.jpg
# test/bicycle/bicycle_0093.jpg
# test/bicycle/bicycle_0094.jpg
# train/bicycle/bicycle_0271.jpg
# train/bicycle/bicycle_0272.jpg
# test/bicycle/bicycle_0095.jpg
# train/bicycle/bicycle_0273.jpg
# train/bicycle/bicycle_0274.jpg
# train/bicycle/bicycle_0275.jpg
# train/bicycle/bicycle_0276.jpg
# train/bicycle/bicycle_0277.jpg
# train/bicycle/bicycle_0278.jpg
# train/bicycle/bicycle_0279.jpg
# train/bicycle/bicycle_0280.jpg
# train/bicycle/bicycle_0281.jpg
# train/bicycle/bicycle_0282.jpg
# train/bicycle/bicycle_0283.jpg
# train/bicycle/bicycle_0284.jpg
# train/bicycle/bicycle_0285.jpg
# test/bicycle/bicycle_0096.jpg
# train/bicycle/bicycle_0286.jpg
# train/bicycle/bicycle_0287.jpg
# train/bicycle/bicycle_0288.jpg
# train/bicycle/bicycle_0289.jpg
# train/bicycle/bicycle_0290.jpg
# train/bicycle/bicycle_0291.jpg
# train/bicycle/bicycle_0292.jpg
# train/bicycle/bicycle_0293.jpg
# train/bicycle/bicycle_0294.jpg
# train/bicycle/bicycle_0295.jpg
# train/bicycle/bicycle_0296.jpg
# train/bicycle/bicycle_0297.jpg
# train/bicycle/bicycle_0298.jpg
# train/bicycle/bicycle_0299.jpg
# train/bicycle/bicycle_0300.jpg
# train/bicycle/bicycle_0301.jpg
# train/bicycle/bicycle_0302.jpg
# test/bicycle/bicycle_0097.jpg
# test/bicycle/bicycle_0098.jpg
# train/bicycle/bicycle_0303.jpg
# train/bicycle/bicycle_0304.jpg
# train/bicycle/bicycle_0305.jpg
# train/bicycle/bicycle_0306.jpg
# train/bicycle/bicycle_0307.jpg
# test/bicycle/bicycle_0099.jpg
# train/bicycle/bicycle_0308.jpg
# train/bicycle/bicycle_0309.jpg
# test/bicycle/bicycle_0100.jpg
# train/bicycle/bicycle_0310.jpg
# train/bicycle/bicycle_0311.jpg
# test/bicycle/bicycle_0101.jpg
# train/bicycle/bicycle_0312.jpg
# train/bicycle/bicycle_0313.jpg
# train/bicycle/bicycle_0314.jpg
# train/bicycle/bicycle_0315.jpg
# test/bicycle/bicycle_0102.jpg
# test/bicycle/bicycle_0103.jpg
# test/bicycle/bicycle_0104.jpg
# train/bicycle/bicycle_0316.jpg
# train/bicycle/bicycle_0317.jpg
# train/bicycle/bicycle_0318.jpg
# train/bicycle/bicycle_0319.jpg
# train/bicycle/bicycle_0320.jpg
# train/bicycle/bicycle_0321.jpg
# train/bicycle/bicycle_0322.jpg
# train/bicycle/bicycle_0323.jpg
# train/bicycle/bicycle_0324.jpg
# train/bicycle/bicycle_0325.jpg
# train/bicycle/bicycle_0326.jpg
# train/bicycle/bicycle_0327.jpg
# train/bicycle/bicycle_0328.jpg
# train/bicycle/bicycle_0329.jpg
# test/bicycle/bicycle_0105.jpg
# test/bicycle/bicycle_0106.jpg
# train/bicycle/bicycle_0330.jpg
# train/bicycle/bicycle_0331.jpg
# test/bicycle/bicycle_0107.jpg
# test/bicycle/bicycle_0108.jpg
# train/bicycle/bicycle_0332.jpg
# train/bicycle/bicycle_0333.jpg
# test/bicycle/bicycle_0109.jpg
# train/bicycle/bicycle_0334.jpg
# train/bicycle/bicycle_0335.jpg
# train/bicycle/bicycle_0336.jpg
# test/bicycle/bicycle_0110.jpg
# test/bicycle/bicycle_0111.jpg
# train/bicycle/bicycle_0337.jpg
# test/bicycle/bicycle_0112.jpg
# train/bicycle/bicycle_0338.jpg
# train/bicycle/bicycle_0339.jpg
# train/bicycle/bicycle_0340.jpg
# train/bicycle/bicycle_0341.jpg
# test/bicycle/bicycle_0113.jpg
# test/bicycle/bicycle_0114.jpg
# train/bicycle/bicycle_0342.jpg
# train/bicycle/bicycle_0343.jpg
# train/bicycle/bicycle_0344.jpg
# train/bicycle/bicycle_0345.jpg
# train/bicycle/bicycle_0346.jpg
# train/bicycle/bicycle_0347.jpg
# train/bicycle/bicycle_0348.jpg
# train/bicycle/bicycle_0349.jpg
# train/bicycle/bicycle_0350.jpg
# train/bicycle/bicycle_0351.jpg
# train/bicycle/bicycle_0352.jpg
# train/bicycle/bicycle_0353.jpg
# train/bicycle/bicycle_0354.jpg
# test/bicycle/bicycle_0115.jpg
# train/bicycle/bicycle_0355.jpg
# train/bicycle/bicycle_0356.jpg
# train/bicycle/bicycle_0357.jpg
# train/bicycle/bicycle_0358.jpg
# train/bicycle/bicycle_0359.jpg
# train/bicycle/bicycle_0360.jpg
# train/bicycle/bicycle_0361.jpg
# test/bicycle/bicycle_0116.jpg
# test/bicycle/bicycle_0117.jpg
# test/bicycle/bicycle_0118.jpg
# train/bicycle/bicycle_0362.jpg
# train/bicycle/bicycle_0363.jpg
# test/bicycle/bicycle_0119.jpg
# train/bicycle/bicycle_0364.jpg
# train/bicycle/bicycle_0365.jpg
# train/bicycle/bicycle_0366.jpg
# train/bicycle/bicycle_0367.jpg
# train/bicycle/bicycle_0368.jpg
# test/bicycle/bicycle_0120.jpg
# train/bicycle/bicycle_0369.jpg
# train/bicycle/bicycle_0370.jpg
# train/bicycle/bicycle_0371.jpg
# test/bicycle/bicycle_0121.jpg
# train/bicycle/bicycle_0372.jpg
# test/bicycle/bicycle_0122.jpg
# train/bicycle/bicycle_0373.jpg
# train/bicycle/bicycle_0374.jpg
# train/bicycle/bicycle_0375.jpg
# train/bicycle/bicycle_0376.jpg
# train/bicycle/bicycle_0377.jpg
# train/bicycle/bicycle_0378.jpg
# train/bicycle/bicycle_0379.jpg
# train/bicycle/bicycle_0380.jpg
# train/bicycle/bicycle_0381.jpg
# train/bicycle/bicycle_0382.jpg
# train/bicycle/bicycle_0383.jpg
# train/bicycle/bicycle_0384.jpg
# test/bicycle/bicycle_0123.jpg
# train/bicycle/bicycle_0385.jpg
# train/bicycle/bicycle_0386.jpg
# train/bicycle/bicycle_0387.jpg
# train/bicycle/bicycle_0388.jpg
# train/bicycle/bicycle_0389.jpg
# train/bicycle/bicycle_0390.jpg
# train/bicycle/bicycle_0391.jpg
# train/bicycle/bicycle_0392.jpg
# test/bicycle/bicycle_0124.jpg
# test/bicycle/bicycle_0125.jpg
# train/bicycle/bicycle_0393.jpg
# test/bicycle/bicycle_0126.jpg
# train/bicycle/bicycle_0394.jpg
# test/bicycle/bicycle_0127.jpg
# train/bicycle/bicycle_0395.jpg
# train/bicycle/bicycle_0396.jpg
# test/bicycle/bicycle_0128.jpg
# train/bicycle/bicycle_0397.jpg
# train/bicycle/bicycle_0398.jpg
# train/bicycle/bicycle_0399.jpg
# train/bicycle/bicycle_0400.jpg
# train/bicycle/bicycle_0401.jpg
# train/bicycle/bicycle_0402.jpg
# train/bicycle/bicycle_0403.jpg
# train/bicycle/bicycle_0404.jpg
# train/bicycle/bicycle_0405.jpg
# test/bicycle/bicycle_0129.jpg
# train/bicycle/bicycle_0406.jpg
# train/bicycle/bicycle_0407.jpg
# test/bicycle/bicycle_0130.jpg
# train/bicycle/bicycle_0408.jpg
# train/bicycle/bicycle_0409.jpg
# train/bicycle/bicycle_0410.jpg
# train/bicycle/bicycle_0411.jpg
# train/bicycle/bicycle_0412.jpg
# train/bicycle/bicycle_0413.jpg
# train/bicycle/bicycle_0414.jpg
# train/bicycle/bicycle_0415.jpg
# train/bicycle/bicycle_0416.jpg
# test/bicycle/bicycle_0131.jpg
# test/bicycle/bicycle_0132.jpg
# test/bicycle/bicycle_0133.jpg
# train/bicycle/bicycle_0417.jpg
# test/bicycle/bicycle_0134.jpg
# train/bicycle/bicycle_0418.jpg
# train/bicycle/bicycle_0419.jpg
# train/bicycle/bicycle_0420.jpg
# train/bicycle/bicycle_0421.jpg
# test/bicycle/bicycle_0135.jpg
# train/bicycle/bicycle_0422.jpg
# train/bicycle/bicycle_0423.jpg
# test/bicycle/bicycle_0136.jpg
# train/bicycle/bicycle_0424.jpg
# train/bicycle/bicycle_0425.jpg
# train/bicycle/bicycle_0426.jpg
# train/bicycle/bicycle_0427.jpg
# train/bicycle/bicycle_0428.jpg
# train/bicycle/bicycle_0429.jpg
# train/bicycle/bicycle_0430.jpg
# train/bicycle/bicycle_0431.jpg
# train/bicycle/bicycle_0432.jpg
# train/bicycle/bicycle_0433.jpg
# test/bicycle/bicycle_0137.jpg
# train/bicycle/bicycle_0434.jpg
# train/bicycle/bicycle_0435.jpg
# train/bicycle/bicycle_0436.jpg
# train/bicycle/bicycle_0437.jpg
# train/bicycle/bicycle_0438.jpg
# train/bicycle/bicycle_0439.jpg
# test/bicycle/bicycle_0138.jpg
# train/bicycle/bicycle_0440.jpg
# train/bicycle/bicycle_0441.jpg
# test/bicycle/bicycle_0139.jpg
# train/bicycle/bicycle_0442.jpg
# train/bicycle/bicycle_0443.jpg
# train/bicycle/bicycle_0444.jpg
# train/bicycle/bicycle_0445.jpg
# train/bicycle/bicycle_0446.jpg
# train/bicycle/bicycle_0447.jpg
# train/bicycle/bicycle_0448.jpg
# test/bicycle/bicycle_0140.jpg
# train/bicycle/bicycle_0449.jpg
# train/bicycle/bicycle_0450.jpg
# train/bicycle/bicycle_0451.jpg
# train/bicycle/bicycle_0452.jpg
# train/bicycle/bicycle_0453.jpg
# test/bicycle/bicycle_0141.jpg
# test/bicycle/bicycle_0142.jpg
# train/bicycle/bicycle_0454.jpg
# train/bicycle/bicycle_0455.jpg
# test/bicycle/bicycle_0143.jpg
# train/bicycle/bicycle_0456.jpg
# test/bicycle/bicycle_0144.jpg
# train/bicycle/bicycle_0457.jpg
# test/bicycle/bicycle_0145.jpg
# train/bicycle/bicycle_0458.jpg
# train/bicycle/bicycle_0459.jpg
# train/bicycle/bicycle_0460.jpg
# train/bicycle/bicycle_0461.jpg
# test/bicycle/bicycle_0146.jpg
# train/bicycle/bicycle_0462.jpg
# train/bicycle/bicycle_0463.jpg
# train/bicycle/bicycle_0464.jpg
# test/bicycle/bicycle_0147.jpg
# train/bicycle/bicycle_0465.jpg
# test/bicycle/bicycle_0148.jpg
# train/bicycle/bicycle_0466.jpg
# train/bicycle/bicycle_0467.jpg
# train/bicycle/bicycle_0468.jpg
# train/bicycle/bicycle_0469.jpg
# train/bicycle/bicycle_0470.jpg
# train/bicycle/bicycle_0471.jpg
# train/bicycle/bicycle_0472.jpg
# train/bicycle/bicycle_0473.jpg
# train/bicycle/bicycle_0474.jpg
# train/bicycle/bicycle_0475.jpg
# train/bicycle/bicycle_0476.jpg
# train/bicycle/bicycle_0477.jpg
# train/bicycle/bicycle_0478.jpg
# train/bicycle/bicycle_0479.jpg
# train/bicycle/bicycle_0480.jpg
# train/bicycle/bicycle_0481.jpg
# train/bicycle/bicycle_0482.jpg
# train/bicycle/bicycle_0483.jpg
# train/bicycle/bicycle_0484.jpg
# train/bicycle/bicycle_0485.jpg
# test/bicycle/bicycle_0149.jpg
# train/bicycle/bicycle_0486.jpg
# train/bicycle/bicycle_0487.jpg
# train/bicycle/bicycle_0488.jpg
# test/bicycle/bicycle_0150.jpg
# test/bicycle/bicycle_0151.jpg
# train/bicycle/bicycle_0489.jpg
# train/bicycle/bicycle_0490.jpg
# test/bicycle/bicycle_0152.jpg
# train/bicycle/bicycle_0491.jpg
# train/bicycle/bicycle_0492.jpg
# train/bicycle/bicycle_0493.jpg
# train/bicycle/bicycle_0494.jpg
# train/bicycle/bicycle_0495.jpg
# train/bicycle/bicycle_0496.jpg
# train/bicycle/bicycle_0497.jpg
# train/bicycle/bicycle_0498.jpg
# test/bicycle/bicycle_0153.jpg
# train/bicycle/bicycle_0499.jpg
# train/bicycle/bicycle_0500.jpg
# train/bicycle/bicycle_0501.jpg
# train/bicycle/bicycle_0502.jpg
# train/bicycle/bicycle_0503.jpg
# train/bicycle/bicycle_0504.jpg
# test/bicycle/bicycle_0154.jpg
# test/bicycle/bicycle_0155.jpg
# train/bicycle/bicycle_0505.jpg
# test/bicycle/bicycle_0156.jpg
# test/bicycle/bicycle_0157.jpg
# train/bicycle/bicycle_0506.jpg
# train/bicycle/bicycle_0507.jpg
# train/bicycle/bicycle_0508.jpg
# test/bicycle/bicycle_0158.jpg
# train/bicycle/bicycle_0509.jpg
# test/bicycle/bicycle_0159.jpg
# train/bicycle/bicycle_0510.jpg
# train/bicycle/bicycle_0511.jpg
# test/bicycle/bicycle_0160.jpg
# train/bicycle/bicycle_0512.jpg
# train/bicycle/bicycle_0513.jpg
# train/bicycle/bicycle_0514.jpg
# train/bicycle/bicycle_0515.jpg
# train/bicycle/bicycle_0516.jpg
# train/bicycle/bicycle_0517.jpg
# train/bicycle/bicycle_0518.jpg
# test/bicycle/bicycle_0161.jpg
# test/bicycle/bicycle_0162.jpg
# train/bicycle/bicycle_0519.jpg
# train/bicycle/bicycle_0520.jpg
# test/bicycle/bicycle_0163.jpg
# train/bicycle/bicycle_0521.jpg
# train/bicycle/bicycle_0522.jpg
# train/bicycle/bicycle_0523.jpg
# train/bicycle/bicycle_0524.jpg
# train/bicycle/bicycle_0525.jpg
# train/bicycle/bicycle_0526.jpg
# train/bicycle/bicycle_0527.jpg
# train/bicycle/bicycle_0528.jpg
# test/bicycle/bicycle_0164.jpg
# train/bicycle/bicycle_0529.jpg
# train/bicycle/bicycle_0530.jpg
# train/bicycle/bicycle_0531.jpg
# test/bicycle/bicycle_0165.jpg
# train/bicycle/bicycle_0532.jpg
# train/bicycle/bicycle_0533.jpg
# train/bicycle/bicycle_0534.jpg
# test/bicycle/bicycle_0166.jpg
# train/bicycle/bicycle_0535.jpg
# train/bicycle/bicycle_0536.jpg
# train/bicycle/bicycle_0537.jpg
# train/bicycle/bicycle_0538.jpg
# train/bicycle/bicycle_0539.jpg
# train/bicycle/bicycle_0540.jpg
# train/bicycle/bicycle_0541.jpg
# train/bicycle/bicycle_0542.jpg
# train/bicycle/bicycle_0543.jpg
# test/bicycle/bicycle_0167.jpg
# train/bicycle/bicycle_0544.jpg
# train/bicycle/bicycle_0545.jpg
# train/bicycle/bicycle_0546.jpg
# train/bicycle/bicycle_0547.jpg
# train/bicycle/bicycle_0548.jpg
# train/bicycle/bicycle_0549.jpg
# train/bicycle/bicycle_0550.jpg
# test/bicycle/bicycle_0168.jpg
# train/bicycle/bicycle_0551.jpg
# test/bicycle/bicycle_0169.jpg
# test/bicycle/bicycle_0170.jpg
# test/bicycle/bicycle_0171.jpg
# train/bicycle/bicycle_0552.jpg
# train/bicycle/bicycle_0553.jpg
# test/bicycle/bicycle_0172.jpg
# train/bicycle/bicycle_0554.jpg
# train/bicycle/bicycle_0555.jpg
# test/bicycle/bicycle_0173.jpg
# train/bicycle/bicycle_0556.jpg
# train/bicycle/bicycle_0557.jpg
# train/bicycle/bicycle_0558.jpg
# train/bicycle/bicycle_0559.jpg
# train/bicycle/bicycle_0560.jpg
# train/bicycle/bicycle_0561.jpg
# test/bicycle/bicycle_0174.jpg
# train/bicycle/bicycle_0562.jpg
# train/bicycle/bicycle_0563.jpg
# train/bicycle/bicycle_0564.jpg
# test/bicycle/bicycle_0175.jpg
# train/bicycle/bicycle_0565.jpg
# train/bicycle/bicycle_0566.jpg
# train/bicycle/bicycle_0567.jpg
# train/bicycle/bicycle_0568.jpg
# train/bicycle/bicycle_0569.jpg
# train/bicycle/bicycle_0570.jpg
# test/bicycle/bicycle_0176.jpg
# test/bicycle/bicycle_0177.jpg
# test/bicycle/bicycle_0178.jpg
# train/bicycle/bicycle_0571.jpg
# train/bicycle/bicycle_0572.jpg
# train/bicycle/bicycle_0573.jpg
# train/bicycle/bicycle_0574.jpg
# train/bicycle/bicycle_0575.jpg
# train/bicycle/bicycle_0576.jpg
# test/bicycle/bicycle_0179.jpg
# test/bicycle/bicycle_0180.jpg
# train/bicycle/bicycle_0577.jpg
# train/bicycle/bicycle_0578.jpg
# train/bicycle/bicycle_0579.jpg
# train/bicycle/bicycle_0580.jpg
# test/bicycle/bicycle_0181.jpg
# train/bicycle/bicycle_0581.jpg
# test/bicycle/bicycle_0182.jpg
# train/bicycle/bicycle_0582.jpg
# train/bicycle/bicycle_0583.jpg
# test/bicycle/bicycle_0183.jpg
# test/bicycle/bicycle_0184.jpg
# train/bicycle/bicycle_0584.jpg
# train/bicycle/bicycle_0585.jpg
# train/bicycle/bicycle_0586.jpg
# train/bicycle/bicycle_0587.jpg
# train/bicycle/bicycle_0588.jpg
# train/bicycle/bicycle_0589.jpg
# train/bicycle/bicycle_0590.jpg
# train/bicycle/bicycle_0591.jpg
# test/bicycle/bicycle_0185.jpg
# train/bicycle/bicycle_0592.jpg
# train/bicycle/bicycle_0593.jpg
# train/bicycle/bicycle_0594.jpg
# train/bicycle/bicycle_0595.jpg
# train/bicycle/bicycle_0596.jpg
# train/bicycle/bicycle_0597.jpg
# train/bicycle/bicycle_0598.jpg
# train/bicycle/bicycle_0599.jpg
# train/bicycle/bicycle_0600.jpg
# test/bicycle/bicycle_0186.jpg
# train/bicycle/bicycle_0601.jpg
# train/bicycle/bicycle_0602.jpg
# train/bicycle/bicycle_0603.jpg
# test/bicycle/bicycle_0187.jpg
# train/bicycle/bicycle_0604.jpg
# test/bicycle/bicycle_0188.jpg
# test/bicycle/bicycle_0189.jpg
# test/bicycle/bicycle_0190.jpg
# test/bicycle/bicycle_0191.jpg
# test/bicycle/bicycle_0192.jpg
# test/bicycle/bicycle_0193.jpg
# test/bicycle/bicycle_0194.jpg
# train/bicycle/bicycle_0605.jpg
# train/bicycle/bicycle_0606.jpg
# train/bicycle/bicycle_0607.jpg
# test/bicycle/bicycle_0195.jpg
# train/bicycle/bicycle_0608.jpg
# train/bicycle/bicycle_0609.jpg
# train/bicycle/bicycle_0610.jpg
# train/bicycle/bicycle_0611.jpg
# test/bicycle/bicycle_0196.jpg
# train/bicycle/bicycle_0612.jpg
# train/bicycle/bicycle_0613.jpg
# train/bicycle/bicycle_0614.jpg
# test/bicycle/bicycle_0197.jpg
# train/bicycle/bicycle_0615.jpg
# train/bicycle/bicycle_0616.jpg
# train/bicycle/bicycle_0617.jpg
# train/bicycle/bicycle_0618.jpg
# train/bicycle/bicycle_0619.jpg
# test/bicycle/bicycle_0198.jpg
# train/bicycle/bicycle_0620.jpg
# train/bicycle/bicycle_0621.jpg
# train/bicycle/bicycle_0622.jpg
# train/bicycle/bicycle_0623.jpg
# train/bicycle/bicycle_0624.jpg
# train/bicycle/bicycle_0625.jpg
# train/bicycle/bicycle_0626.jpg
# train/bicycle/bicycle_0627.jpg
# train/bicycle/bicycle_0628.jpg
# train/bicycle/bicycle_0629.jpg
# train/bicycle/bicycle_0630.jpg
# train/bicycle/bicycle_0631.jpg
# train/bicycle/bicycle_0632.jpg
# test/bicycle/bicycle_0199.jpg
# train/bicycle/bicycle_0633.jpg
# train/bicycle/bicycle_0634.jpg
# test/bicycle/bicycle_0200.jpg
# train/bicycle/bicycle_0635.jpg
# train/bicycle/bicycle_0636.jpg
# test/bicycle/bicycle_0201.jpg
# train/bicycle/bicycle_0637.jpg
# train/bicycle/bicycle_0638.jpg
# test/bicycle/bicycle_0202.jpg
# train/bicycle/bicycle_0639.jpg
# test/bicycle/bicycle_0203.jpg
# test/bicycle/bicycle_0204.jpg
# train/bicycle/bicycle_0640.jpg
# train/bicycle/bicycle_0641.jpg
# train/bicycle/bicycle_0642.jpg
# test/bicycle/bicycle_0205.jpg
# test/bicycle/bicycle_0206.jpg
# train/bicycle/bicycle_0643.jpg
# test/bicycle/bicycle_0207.jpg
# test/bicycle/bicycle_0208.jpg
# train/bicycle/bicycle_0644.jpg
# train/bicycle/bicycle_0645.jpg
# train/bicycle/bicycle_0646.jpg
# train/bicycle/bicycle_0647.jpg
# train/bicycle/bicycle_0648.jpg
# train/bicycle/bicycle_0649.jpg
# train/bicycle/bicycle_0650.jpg
# test/bicycle/bicycle_0209.jpg
# test/bicycle/bicycle_0210.jpg
# train/bicycle/bicycle_0651.jpg
# train/bicycle/bicycle_0652.jpg
# test/bicycle/bicycle_0211.jpg
# train/bicycle/bicycle_0653.jpg
# train/bicycle/bicycle_0654.jpg
# train/bicycle/bicycle_0655.jpg
# train/bicycle/bicycle_0656.jpg
# train/bicycle/bicycle_0657.jpg
# train/bicycle/bicycle_0658.jpg
# train/bicycle/bicycle_0659.jpg
# test/bicycle/bicycle_0212.jpg
# train/bicycle/bicycle_0660.jpg
# test/bicycle/bicycle_0213.jpg
# train/bicycle/bicycle_0661.jpg
# train/bicycle/bicycle_0662.jpg
# train/bicycle/bicycle_0663.jpg
# train/bicycle/bicycle_0664.jpg
# train/bicycle/bicycle_0665.jpg
# test/bicycle/bicycle_0214.jpg
# test/bicycle/bicycle_0215.jpg
# train/bicycle/bicycle_0666.jpg
# train/bicycle/bicycle_0667.jpg
# train/bicycle/bicycle_0668.jpg
# train/bicycle/bicycle_0669.jpg
# train/bicycle/bicycle_0670.jpg
# train/bicycle/bicycle_0671.jpg
# train/bicycle/bicycle_0672.jpg
# test/bicycle/bicycle_0216.jpg
# train/bicycle/bicycle_0673.jpg
# train/bicycle/bicycle_0674.jpg
# test/bicycle/bicycle_0217.jpg
# train/bicycle/bicycle_0675.jpg
# train/bicycle/bicycle_0676.jpg
# train/bicycle/bicycle_0677.jpg
# train/bicycle/bicycle_0678.jpg
# test/bicycle/bicycle_0218.jpg
# test/bicycle/bicycle_0219.jpg
# train/bicycle/bicycle_0679.jpg
# test/bicycle/bicycle_0220.jpg
# test/bicycle/bicycle_0221.jpg
# test/bicycle/bicycle_0222.jpg
# train/bicycle/bicycle_0680.jpg
# train/bicycle/bicycle_0681.jpg
# train/bicycle/bicycle_0682.jpg
# train/bicycle/bicycle_0683.jpg
# train/bicycle/bicycle_0684.jpg
# train/bicycle/bicycle_0685.jpg
# train/bicycle/bicycle_0686.jpg
# train/bicycle/bicycle_0687.jpg
# train/bicycle/bicycle_0688.jpg
# train/bicycle/bicycle_0689.jpg
# train/bicycle/bicycle_0690.jpg
# train/bicycle/bicycle_0691.jpg
# train/bicycle/bicycle_0692.jpg
# train/bicycle/bicycle_0693.jpg
# test/bicycle/bicycle_0223.jpg
# train/bicycle/bicycle_0694.jpg
# train/bicycle/bicycle_0695.jpg
# test/bicycle/bicycle_0224.jpg
# train/bicycle/bicycle_0696.jpg
# train/bicycle/bicycle_0697.jpg
# train/bicycle/bicycle_0698.jpg
# train/bicycle/bicycle_0699.jpg
# train/bicycle/bicycle_0700.jpg
# train/bicycle/bicycle_0701.jpg
# train/bicycle/bicycle_0702.jpg
# train/bicycle/bicycle_0703.jpg
# train/bicycle/bicycle_0704.jpg
# test/bicycle/bicycle_0225.jpg
# train/bicycle/bicycle_0705.jpg
# train/bicycle/bicycle_0706.jpg
# train/bicycle/bicycle_0707.jpg
# test/bicycle/bicycle_0226.jpg
# train/bicycle/bicycle_0708.jpg
# train/bicycle/bicycle_0709.jpg
# train/bicycle/bicycle_0710.jpg
# train/bicycle/bicycle_0711.jpg
# test/bicycle/bicycle_0227.jpg
# train/bicycle/bicycle_0712.jpg
# train/bicycle/bicycle_0713.jpg
# test/bicycle/bicycle_0228.jpg
# train/bicycle/bicycle_0714.jpg
# train/bicycle/bicycle_0715.jpg
# test/bicycle/bicycle_0229.jpg
# train/bicycle/bicycle_0716.jpg
# train/bicycle/bicycle_0717.jpg
# train/bicycle/bicycle_0718.jpg
# test/bicycle/bicycle_0230.jpg
# test/bicycle/bicycle_0231.jpg
# train/bicycle/bicycle_0719.jpg
# train/bicycle/bicycle_0720.jpg
# train/bicycle/bicycle_0721.jpg
# train/bicycle/bicycle_0722.jpg
# train/bicycle/bicycle_0723.jpg
# train/bicycle/bicycle_0724.jpg
# train/bicycle/bicycle_0725.jpg
# train/bicycle/bicycle_0726.jpg
# train/bicycle/bicycle_0727.jpg
# test/bicycle/bicycle_0232.jpg
# train/bicycle/bicycle_0728.jpg
# train/bicycle/bicycle_0729.jpg
# train/bicycle/bicycle_0730.jpg
# train/bicycle/bicycle_0731.jpg
# train/bicycle/bicycle_0732.jpg
# train/bicycle/bicycle_0733.jpg
# train/bicycle/bicycle_0734.jpg
# test/bicycle/bicycle_0233.jpg
# train/bicycle/bicycle_0735.jpg
# test/bicycle/bicycle_0234.jpg
# train/bicycle/bicycle_0736.jpg
# train/bicycle/bicycle_0737.jpg
# test/bicycle/bicycle_0235.jpg
# train/bicycle/bicycle_0738.jpg
# train/bicycle/bicycle_0739.jpg
# train/bicycle/bicycle_0740.jpg
# test/bicycle/bicycle_0236.jpg
# test/bicycle/bicycle_0237.jpg
# train/bicycle/bicycle_0741.jpg
# train/bicycle/bicycle_0742.jpg
# test/bicycle/bicycle_0238.jpg
# train/bicycle/bicycle_0743.jpg
# train/bicycle/bicycle_0744.jpg
# train/bicycle/bicycle_0745.jpg
# train/bicycle/bicycle_0746.jpg
# train/bicycle/bicycle_0747.jpg
# train/bicycle/bicycle_0748.jpg
# test/bicycle/bicycle_0239.jpg
# train/bicycle/bicycle_0749.jpg
# test/bicycle/bicycle_0240.jpg
# test/bicycle/bicycle_0241.jpg
# train/bicycle/bicycle_0750.jpg
# train/bicycle/bicycle_0751.jpg
# train/bicycle/bicycle_0752.jpg
# train/bicycle/bicycle_0753.jpg
# test/bicycle/bicycle_0242.jpg
# train/bicycle/bicycle_0754.jpg
# train/bicycle/bicycle_0755.jpg
# train/bicycle/bicycle_0756.jpg
# train/bicycle/bicycle_0757.jpg
# train/bicycle/bicycle_0758.jpg
# train/bicycle/bicycle_0759.jpg
# train/bicycle/bicycle_0760.jpg
# train/bicycle/bicycle_0761.jpg
# test/bicycle/bicycle_0243.jpg
# train/bicycle/bicycle_0762.jpg
# train/bicycle/bicycle_0763.jpg
# train/bicycle/bicycle_0764.jpg
# train/bicycle/bicycle_0765.jpg
# train/bicycle/bicycle_0766.jpg
# train/bicycle/bicycle_0767.jpg
# train/bicycle/bicycle_0768.jpg
# train/bicycle/bicycle_0769.jpg
# train/bicycle/bicycle_0770.jpg
# train/bicycle/bicycle_0771.jpg
# train/bicycle/bicycle_0772.jpg
# train/bicycle/bicycle_0773.jpg
# train/bicycle/bicycle_0774.jpg
# test/bicycle/bicycle_0244.jpg
# train/bicycle/bicycle_0775.jpg
# train/bicycle/bicycle_0776.jpg
# train/bicycle/bicycle_0777.jpg
# train/bicycle/bicycle_0778.jpg
# train/bicycle/bicycle_0779.jpg
# train/bicycle/bicycle_0780.jpg
# test/bicycle/bicycle_0245.jpg
# test/bicycle/bicycle_0246.jpg
# train/bicycle/bicycle_0781.jpg
# train/bicycle/bicycle_0782.jpg
# train/bicycle/bicycle_0783.jpg
# train/bicycle/bicycle_0784.jpg
# train/bicycle/bicycle_0785.jpg
# train/bicycle/bicycle_0786.jpg
# train/bicycle/bicycle_0787.jpg
# train/bicycle/bicycle_0788.jpg
# train/bicycle/bicycle_0789.jpg
# train/bicycle/bicycle_0790.jpg
# train/bicycle/bicycle_0791.jpg
# train/bicycle/bicycle_0792.jpg
# train/bicycle/bicycle_0793.jpg
# train/bicycle/bicycle_0794.jpg
# test/bicycle/bicycle_0247.jpg
# train/bicycle/bicycle_0795.jpg
# train/bicycle/bicycle_0796.jpg
# train/bicycle/bicycle_0797.jpg
# train/bicycle/bicycle_0798.jpg
# train/bicycle/bicycle_0799.jpg
# train/bicycle/bicycle_0800.jpg
# train/bicycle/bicycle_0801.jpg
# train/bicycle/bicycle_0802.jpg
# test/bicycle/bicycle_0248.jpg
# train/bicycle/bicycle_0803.jpg
# train/bicycle/bicycle_0804.jpg
# train/bicycle/bicycle_0805.jpg
# train/bicycle/bicycle_0806.jpg
# train/bicycle/bicycle_0807.jpg
# train/bicycle/bicycle_0808.jpg
# train/bicycle/bicycle_0809.jpg
# train/bicycle/bicycle_0810.jpg
# train/bicycle/bicycle_0811.jpg
# train/bicycle/bicycle_0812.jpg
# train/bicycle/bicycle_0813.jpg
# train/bicycle/bicycle_0814.jpg
# train/bicycle/bicycle_0815.jpg
# train/bicycle/bicycle_0816.jpg
# train/bicycle/bicycle_0817.jpg
# train/bicycle/bicycle_0818.jpg
# train/bicycle/bicycle_0819.jpg
# train/bicycle/bicycle_0820.jpg
# train/bicycle/bicycle_0821.jpg
# test/bicycle/bicycle_0249.jpg
# train/bicycle/bicycle_0822.jpg
# train/bicycle/bicycle_0823.jpg
# train/bicycle/bicycle_0824.jpg
# train/bicycle/bicycle_0825.jpg
# train/bicycle/bicycle_0826.jpg
# train/bicycle/bicycle_0827.jpg
# test/bicycle/bicycle_0250.jpg
# train/bicycle/bicycle_0828.jpg
# test/bicycle/bicycle_0251.jpg
# train/bicycle/bicycle_0829.jpg
# test/bicycle/bicycle_0252.jpg
# train/bicycle/bicycle_0830.jpg
# test/bicycle/bicycle_0253.jpg
# train/bicycle/bicycle_0831.jpg
# train/bicycle/bicycle_0832.jpg
# train/bicycle/bicycle_0833.jpg
# train/bicycle/bicycle_0834.jpg
# train/bicycle/bicycle_0835.jpg
# train/bicycle/bicycle_0836.jpg
# train/bicycle/bicycle_0837.jpg
# test/bicycle/bicycle_0254.jpg
# train/bicycle/bicycle_0838.jpg
# train/bicycle/bicycle_0839.jpg
# train/bicycle/bicycle_0840.jpg
# train/bicycle/bicycle_0841.jpg
# train/bicycle/bicycle_0842.jpg
# train/bicycle/bicycle_0843.jpg
# train/bicycle/bicycle_0844.jpg
# train/bicycle/bicycle_0845.jpg
# train/bicycle/bicycle_0846.jpg
# train/bicycle/bicycle_0847.jpg
# train/bicycle/bicycle_0848.jpg
# train/bicycle/bicycle_0849.jpg
# train/bicycle/bicycle_0850.jpg
# train/bicycle/bicycle_0851.jpg
# train/bicycle/bicycle_0852.jpg
# train/bicycle/bicycle_0853.jpg
# train/bicycle/bicycle_0854.jpg
# train/bicycle/bicycle_0855.jpg
# test/bicycle/bicycle_0255.jpg
# train/bicycle/bicycle_0856.jpg
# train/bicycle/bicycle_0857.jpg
# train/bicycle/bicycle_0858.jpg
# train/bicycle/bicycle_0859.jpg
# train/bicycle/bicycle_0860.jpg
# train/bicycle/bicycle_0861.jpg
# test/bicycle/bicycle_0256.jpg
# train/bicycle/bicycle_0862.jpg
# test/bicycle/bicycle_0257.jpg
# train/bicycle/bicycle_0863.jpg
# test/bicycle/bicycle_0258.jpg
# test/bicycle/bicycle_0259.jpg
# train/bicycle/bicycle_0864.jpg
# test/bicycle/bicycle_0260.jpg
# train/bicycle/bicycle_0865.jpg
# test/bicycle/bicycle_0261.jpg
# train/bicycle/bicycle_0866.jpg
# train/bicycle/bicycle_0867.jpg
# train/bicycle/bicycle_0868.jpg
# train/bicycle/bicycle_0869.jpg
# train/bicycle/bicycle_0870.jpg
# train/bicycle/bicycle_0871.jpg
# test/bicycle/bicycle_0262.jpg
# train/bicycle/bicycle_0872.jpg
# train/bicycle/bicycle_0873.jpg
# test/bicycle/bicycle_0263.jpg
# test/bicycle/bicycle_0264.jpg
# train/bicycle/bicycle_0874.jpg
# train/bicycle/bicycle_0875.jpg
# train/bicycle/bicycle_0876.jpg
# test/bicycle/bicycle_0265.jpg
# train/bicycle/bicycle_0877.jpg
# train/bicycle/bicycle_0878.jpg
# train/bicycle/bicycle_0879.jpg
# train/bicycle/bicycle_0880.jpg
# test/bicycle/bicycle_0266.jpg
# train/bicycle/bicycle_0881.jpg
# train/bicycle/bicycle_0882.jpg
# train/bicycle/bicycle_0883.jpg
# train/bicycle/bicycle_0884.jpg
# train/bicycle/bicycle_0885.jpg
# train/bicycle/bicycle_0886.jpg
# train/bicycle/bicycle_0887.jpg
# train/bicycle/bicycle_0888.jpg
# train/bicycle/bicycle_0889.jpg
# train/bicycle/bicycle_0890.jpg
# train/bicycle/bicycle_0891.jpg
# train/bicycle/bicycle_0892.jpg
# train/bicycle/bicycle_0893.jpg
# test/bicycle/bicycle_0267.jpg
# test/bicycle/bicycle_0268.jpg
# train/bicycle/bicycle_0894.jpg
# test/bicycle/bicycle_0269.jpg
# test/bicycle/bicycle_0270.jpg
# train/bicycle/bicycle_0895.jpg
# test/bicycle/bicycle_0271.jpg
# train/bicycle/bicycle_0896.jpg
# train/bicycle/bicycle_0897.jpg
# train/bicycle/bicycle_0898.jpg
# train/bicycle/bicycle_0899.jpg
# train/bicycle/bicycle_0900.jpg
# test/bicycle/bicycle_0272.jpg
# train/bicycle/bicycle_0901.jpg
# test/bicycle/bicycle_0273.jpg
# train/bicycle/bicycle_0902.jpg
# train/bicycle/bicycle_0903.jpg
# test/bicycle/bicycle_0274.jpg
# train/bicycle/bicycle_0904.jpg
# train/bicycle/bicycle_0905.jpg
# train/bicycle/bicycle_0906.jpg
# train/bicycle/bicycle_0907.jpg
# train/bicycle/bicycle_0908.jpg
# test/bicycle/bicycle_0275.jpg
# train/bicycle/bicycle_0909.jpg
# train/bicycle/bicycle_0910.jpg
# train/bicycle/bicycle_0911.jpg
# train/bicycle/bicycle_0912.jpg
# train/bicycle/bicycle_0913.jpg
# train/bicycle/bicycle_0914.jpg
# test/bicycle/bicycle_0276.jpg
# train/bicycle/bicycle_0915.jpg
# train/bicycle/bicycle_0916.jpg
# train/bicycle/bicycle_0917.jpg
# train/bicycle/bicycle_0918.jpg
# train/bicycle/bicycle_0919.jpg
# test/bicycle/bicycle_0277.jpg
# train/bicycle/bicycle_0920.jpg
# test/bicycle/bicycle_0278.jpg
# train/bicycle/bicycle_0921.jpg
# test/bicycle/bicycle_0279.jpg
# train/bicycle/bicycle_0922.jpg
# train/bicycle/bicycle_0923.jpg
# train/bicycle/bicycle_0924.jpg
# train/bicycle/bicycle_0925.jpg
# test/bicycle/bicycle_0280.jpg
# train/bicycle/bicycle_0926.jpg
# train/bicycle/bicycle_0927.jpg
# train/bicycle/bicycle_0928.jpg
# train/bicycle/bicycle_0929.jpg
# train/bicycle/bicycle_0930.jpg
# train/bicycle/bicycle_0931.jpg
# train/bicycle/bicycle_0932.jpg
# train/bicycle/bicycle_0933.jpg
# train/bicycle/bicycle_0934.jpg
# train/bicycle/bicycle_0935.jpg
# train/bicycle/bicycle_0936.jpg
# test/bicycle/bicycle_0281.jpg
# test/bicycle/bicycle_0282.jpg
# train/bicycle/bicycle_0937.jpg
# train/bicycle/bicycle_0938.jpg
# train/bicycle/bicycle_0939.jpg
# train/bicycle/bicycle_0940.jpg
# train/bicycle/bicycle_0941.jpg
# train/bicycle/bicycle_0942.jpg
# train/bicycle/bicycle_0943.jpg
# train/bicycle/bicycle_0944.jpg
# test/bicycle/bicycle_0283.jpg
# train/bicycle/bicycle_0945.jpg
# train/bicycle/bicycle_0946.jpg
# test/bicycle/bicycle_0284.jpg
# test/bicycle/bicycle_0285.jpg
# test/bicycle/bicycle_0286.jpg
# train/bicycle/bicycle_0947.jpg
# train/bicycle/bicycle_0948.jpg
# train/bicycle/bicycle_0949.jpg
# train/bicycle/bicycle_0950.jpg
# test/bicycle/bicycle_0287.jpg
# train/bicycle/bicycle_0951.jpg
# train/bicycle/bicycle_0952.jpg
# train/bicycle/bicycle_0953.jpg
# test/bicycle/bicycle_0288.jpg
# test/bicycle/bicycle_0289.jpg
# test/bicycle/bicycle_0290.jpg
# train/bicycle/bicycle_0954.jpg
# train/bicycle/bicycle_0955.jpg
# train/bicycle/bicycle_0956.jpg
# train/bicycle/bicycle_0957.jpg
# test/bicycle/bicycle_0291.jpg
# test/bicycle/bicycle_0292.jpg
# train/bicycle/bicycle_0958.jpg
# train/bicycle/bicycle_0959.jpg
# train/bicycle/bicycle_0960.jpg
# train/bicycle/bicycle_0961.jpg
# train/bicycle/bicycle_0962.jpg
# test/bicycle/bicycle_0293.jpg
# train/bicycle/bicycle_0963.jpg
# train/bicycle/bicycle_0964.jpg
# train/bicycle/bicycle_0965.jpg
# train/bicycle/bicycle_0966.jpg
# train/bicycle/bicycle_0967.jpg
# train/bicycle/bicycle_0968.jpg
# train/bicycle/bicycle_0969.jpg
# train/bicycle/bicycle_0970.jpg
# train/bicycle/bicycle_0971.jpg
# train/bicycle/bicycle_0972.jpg
# train/bicycle/bicycle_0973.jpg
# train/bicycle/bicycle_0974.jpg
# train/bicycle/bicycle_0975.jpg
# test/bicycle/bicycle_0294.jpg
# train/bicycle/bicycle_0976.jpg
# train/bicycle/bicycle_0977.jpg
# test/bicycle/bicycle_0295.jpg
# train/bicycle/bicycle_0978.jpg
# train/bicycle/bicycle_0979.jpg
# train/bicycle/bicycle_0980.jpg
# train/bicycle/bicycle_0981.jpg
# test/bicycle/bicycle_0296.jpg
# train/bicycle/bicycle_0982.jpg
# train/bicycle/bicycle_0983.jpg
# train/bicycle/bicycle_0984.jpg
# train/bicycle/bicycle_0985.jpg
# train/bicycle/bicycle_0986.jpg
# train/bicycle/bicycle_0987.jpg
# train/bicycle/bicycle_0988.jpg
# train/bicycle/bicycle_0989.jpg
# train/bicycle/bicycle_0990.jpg
# train/bicycle/bicycle_0991.jpg
# test/bicycle/bicycle_0297.jpg
# train/bicycle/bicycle_0992.jpg
# train/bicycle/bicycle_0993.jpg
# train/bicycle/bicycle_0994.jpg
# test/bicycle/bicycle_0298.jpg
# train/bicycle/bicycle_0995.jpg
# train/bicycle/bicycle_0996.jpg
# train/bicycle/bicycle_0997.jpg
# train/bicycle/bicycle_0998.jpg
# train/bicycle/bicycle_0999.jpg
# test/bicycle/bicycle_0299.jpg
